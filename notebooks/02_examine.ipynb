# %%
from pathlib import Path
import xarray as xr
import os

ncfile = Path(r"C:\Users\lureymondet\GitHub\GOFLOW_LR\data\unzip\20250101130007\W_XX-EUMETSAT-Darmstadt,IMG+SAT,MTI1+FCI-1C-RRAD-FDHSI-FD--CHK-BODY---NC4E_C_EUMT_20250101130737_IDPFI_OPE_20250101130446_20250101130525_N__O_0079_0022.nc")
# ncfile = Path(r"C:\Users\lureymondet\GitHub\GOFLOW_LR\data\unzip\20250101130007\W_XX-EUMETSAT-Darmstadt,IMG+SAT,MTI1+FCI-1C-RRAD-FDHSI-FD--CHK-TRAIL---NC4E_C_EUMT_20250101130306_IDPFI_OPE_20250101130007_20250101130924_N__O_0079_0041.nc")
print(os.path.getsize(ncfile) / 1e6, "MB")

ds = xr.open_dataset(ncfile)
ds
# print(ds.attrs['linked_data'])

# ds['l1c_channels_present']
# ds.sel(l1c_channels_present='vis_04')
# print(ds)
# print(ds.sel(l1c_channels_present='vis_04'))
# Out:
# 35.077277 MB
# <xarray.Dataset> Size: 786B
# Dimensions:               (number_of_l1c_channels: 16, index: 40)
# Coordinates:
#   * index                 (index) uint16 80B 286 287 288 289 ... 322 323 324 325
# Dimensions without coordinates: number_of_l1c_channels
# Data variables:
#     l1c_channels_present  (number_of_l1c_channels) <U6 384B ...
#     time                  (index) datetime64[ns] 320B ...
#     index_offset          uint16 2B ...
# Attributes: (12/70)
#     Conventions:                          CF-1.7
#     title:                                FCI Level 1C Rectified Radiance Pro...
#     summary:                              Flexible Combined Imager (FCI) Leve...
#     keywords:                             MTG FCI Rectified Radiance
#     keywords_vocabulary:                  []
#     history:                              Original generated file
#     ...                                   ...
#     instrument_configuration_id:          16384
# ...
